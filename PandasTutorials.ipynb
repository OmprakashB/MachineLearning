# %%
# Pandas
import pandas as pd
import numpy.random as rand

# Lets create a List
lst1 = [10, 20, 30, 40, 50]
lst2 = [[10, 20, 30, 40, 50], [100, 200, 300, 400, 500, 600]]
df1 = pd.DataFrame(lst1)
df2 = pd.DataFrame(lst2)
print("Dataframe1: \n",df1)
print("Dataframe2: \n", df2)
# Out:
# Dataframe1:
#      0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50
# Dataframe2:
#       0    1    2    3    4      5
# 0   10   20   30   40   50    NaN
# 1  100  200  300  400  500  600.0

# %%
# Lets create a List
from numpy.random import randn
#df = pd.DataFrame(randn(5,4),index='A B C D E'.split(),columns=["W","X","Y","Z"])
df = pd.DataFrame(randn(5,4),index='A,B,C,D,E'.split(','),columns=["W","X","Y","Z"]) # Note for index, split using the separator
df
# Out:
#           W         X         Y         Z
# A  0.933007 -0.447571 -0.265692 -0.077432
# B  0.832000  0.704604 -1.188457  0.656191
# C -0.314697  0.209414  0.149503  0.941467
# D  0.185482  0.634857 -0.343240 -1.276844
# E -0.067704 -0.011976 -0.462781  1.192072

# %%
print(df['W'])
print(df[['X', 'Y', 'Z']])
# Out:
# A    0.933007
# B    0.832000
# C   -0.314697
# D    0.185482
# E   -0.067704
# Name: W, dtype: float64
#           X         Y         Z
# A -0.447571 -0.265692 -0.077432
# B  0.704604 -1.188457  0.656191
# C  0.209414  0.149503  0.941467
# D  0.634857 -0.343240 -1.276844
# E -0.011976 -0.462781  1.192072

# %%
#For accessing the Rows
print(df)
print('\nOperating on the DataFrame rows\n')
print('Printing row with index A:\n',df.loc['A'])
print('\nPrinting row with index A and B:\n',df.loc[['A', 'B']])
print('\nPrinting row at index 2 (C):\n',df.iloc[2])
# Out:
#           W         X         Y         Z
# A  0.933007 -0.447571 -0.265692 -0.077432
# B  0.832000  0.704604 -1.188457  0.656191
# C -0.314697  0.209414  0.149503  0.941467
# D  0.185482  0.634857 -0.343240 -1.276844
# E -0.067704 -0.011976 -0.462781  1.192072
#
# Operating on the DataFrame rows
#
# Printing row with index A:
#  W    0.933007
# X   -0.447571
# Y   -0.265692
# Z   -0.077432
# Name: A, dtype: float64
#
# Printing row with index A and B:
#            W         X         Y         Z
# A  0.933007 -0.447571 -0.265692 -0.077432
# B  0.832000  0.704604 -1.188457  0.656191
#
# Printing 2nd row:
#  W   -0.314697
# X    0.209414
# Y    0.149503
# Z    0.941467
# Name: C, dtype: float64
