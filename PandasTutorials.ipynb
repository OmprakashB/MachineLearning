# %%
# Pandas
import pandas as pd
import numpy.random as rand

# Lets create a List
lst1 = [10, 20, 30, 40, 50]
lst2 = [[10, 20, 30, 40, 50], [100, 200, 300, 400, 500, 600]]
df1 = pd.DataFrame(lst1)
df2 = pd.DataFrame(lst2)
print("Dataframe1: \n",df1)
print("Dataframe2: \n", df2)
# Out:
# Dataframe1:
#      0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50
# Dataframe2:
#       0    1    2    3    4      5
# 0   10   20   30   40   50    NaN
# 1  100  200  300  400  500  600.0

# %%
# Lets create a List
from numpy.random import randn
#df = pd.DataFrame(randn(5,4),index='A B C D E'.split(),columns=["W","X","Y","Z"])
df = pd.DataFrame(randn(5,4),index='A,B,C,D,E'.split(','),columns=["W","X","Y","Z"]) # Note for index, split using the separator
df
# Out:
#           W         X         Y         Z
# A  0.933007 -0.447571 -0.265692 -0.077432
# B  0.832000  0.704604 -1.188457  0.656191
# C -0.314697  0.209414  0.149503  0.941467
# D  0.185482  0.634857 -0.343240 -1.276844
# E -0.067704 -0.011976 -0.462781  1.192072

# %%
print(df['W'])
print(df[['X', 'Y', 'Z']])
# Out:
# A    0.933007
# B    0.832000
# C   -0.314697
# D    0.185482
# E   -0.067704
# Name: W, dtype: float64
#           X         Y         Z
# A -0.447571 -0.265692 -0.077432
# B  0.704604 -1.188457  0.656191
# C  0.209414  0.149503  0.941467
# D  0.634857 -0.343240 -1.276844
# E -0.011976 -0.462781  1.192072

# %%
#For accessing the Rows
#print(df)
print('Operating on the DataFrame rows\n')
print('Printing row with index A:\n',df.loc['A'])
print('\nPrinting row with index A and B:\n',df.loc[['A', 'B']])
print('\nPrinting row at index 2 (C):\n',df.iloc[2], '\n\n')

df
# Out:
# Operating on the DataFrame rows
#
# Printing row with index A:
#  W    0.933007
# X   -0.447571
# Y   -0.265692
# Z   -0.077432
# Name: A, dtype: float64
#
# Printing row with index A and B:
#            W         X         Y         Z
# A  0.933007 -0.447571 -0.265692 -0.077432
# B  0.832000  0.704604 -1.188457  0.656191
#
# Printing row at index 2 (C):
#  W   -0.314697
# X    0.209414
# Y    0.149503
# Z    0.941467
# Name: C, dtype: float64
#           W         X         Y         Z
# A  0.933007 -0.447571 -0.265692 -0.077432
# B  0.832000  0.704604 -1.188457  0.656191
# C -0.314697  0.209414  0.149503  0.941467
# D  0.185482  0.634857 -0.343240 -1.276844
# E -0.067704 -0.011976 -0.462781  1.192072

# %%
#Subset of the DataFrame
print('\nOperating on the DataFrame subset\n')
print('Printing subset:\n',df.loc['C', 'Y'])
print('\nPrinting subset:\n',df.loc[['A', 'C'], ['W','X','Y']], '\n\n')
df
# Out:
# Operating on the DataFrame subset
#
# Printing subset:
#  0.1495029757959719
#
# Printing subset:
#            W         X         Y
# A  0.933007 -0.447571 -0.265692
# C -0.314697  0.209414  0.149503
#           W         X         Y         Z
# A  0.933007 -0.447571 -0.265692 -0.077432
# B  0.832000  0.704604 -1.188457  0.656191
# C -0.314697  0.209414  0.149503  0.941467
# D  0.185482  0.634857 -0.343240 -1.276844
# E -0.067704 -0.011976 -0.462781  1.192072

# %%
#Conditional selection
df > 0      # Returns True for positive and False for negative
# Out:
#        W      X      Y      Z
# A   True  False  False  False
# B   True   True  False   True
# C  False   True   True   True
# D   True   True  False  False
# E  False  False  False   True

# %%
df[df > 0] #Prints out the dataframe view with only positive values and NaN for negative values
# Out:
#           W         X         Y         Z
# A  0.933007       NaN       NaN       NaN
# B  0.832000  0.704604       NaN  0.656191
# C       NaN  0.209414  0.149503  0.941467
# D  0.185482  0.634857       NaN       NaN
# E       NaN       NaN       NaN  1.192072

# %%
df[df['W'] > 0] # Filters and prints the dataframe where value for W are positive
# Out:
#           W         X         Y         Z
# A  0.933007 -0.447571 -0.265692 -0.077432
# B  0.832000  0.704604 -1.188457  0.656191
# D  0.185482  0.634857 -0.343240 -1.276844

# %%
df[df['W'] < 0] # Filters and prints the dataframe where value for W are negative
# Out:
#           W         X         Y         Z
# C -0.314697  0.209414  0.149503  0.941467
# E -0.067704 -0.011976 -0.462781  1.192072

# %%
df #Original DataFrame is not modified

dfand = df[(df['X'] < 0) & (df['Z'] > 1)] #Using and
dfor = df[(df['X'] > 0) | (df['Z'] > 1)] #Using or
print(dfand)
print(dfor)

df
# Out:
#           W         X         Y         Z
# E -0.067704 -0.011976 -0.462781  1.192072
#           W         X         Y         Z
# B  0.832000  0.704604 -1.188457  0.656191
# C -0.314697  0.209414  0.149503  0.941467
# D  0.185482  0.634857 -0.343240 -1.276844
# E -0.067704 -0.011976 -0.462781  1.192072
#           W         X         Y         Z
# A  0.933007 -0.447571 -0.265692 -0.077432
# B  0.832000  0.704604 -1.188457  0.656191
# C -0.314697  0.209414  0.149503  0.941467
# D  0.185482  0.634857 -0.343240 -1.276844
# E -0.067704 -0.011976 -0.462781  1.192072

# %%
#Resetting the index - Explore why?
df.reset_index(inplace = True)
df
# Out:
#   index         W         X         Y         Z
# 0     A  0.933007 -0.447571 -0.265692 -0.077432
# 1     B  0.832000  0.704604 -1.188457  0.656191
# 2     C -0.314697  0.209414  0.149503  0.941467
# 3     D  0.185482  0.634857 -0.343240 -1.276844
# 4     E -0.067704 -0.011976 -0.462781  1.192072

# %%
dfcsv = pd.read_csv('data.csv')
dfcsv # Returns first 5 columns and last 5 columns

print(pd.options.display.max_rows)

pd.options.display.max_rows = 1000 #Updating the display max rows value

dfcsv
# Out:
# 60
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
dfcsv.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
dfcsv.tail()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
dfcsv.head(2)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0

# %%
dfcsv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
dfcsv[dfcsv['Calories'] > 0]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [164 rows x 4 columns]
